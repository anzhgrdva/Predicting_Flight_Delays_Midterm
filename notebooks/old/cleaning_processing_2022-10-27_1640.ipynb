# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta

# %%
# Read from extracted data
flights_df = pd.read_csv('../data/flights_all_2022-10-27_1616.csv')
# Out:
# /var/folders/1m/wlv_4s950j15c3grd3ny62mr0000gn/T/ipykernel_34944/3710073075.py:2: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   flights_df = pd.read_csv('../data/flights_all_2022-10-27_1616.csv')

# %%
flights_df.columns
# Out:
# Index(['mkt_carrier', 'mkt_carrier_fl_num', 'fl_date', 'branded_code_share',
#        'op_unique_carrier', 'op_carrier_fl_num', 'origin_airport_id',
#        'origin_city_name', 'dest_airport_id', 'dest_city_name', 'crs_dep_time',
#        'dep_time', 'dep_delay', 'taxi_out', 'taxi_in', 'crs_arr_time',
#        'arr_time', 'arr_delay', 'cancelled', 'cancellation_code', 'diverted',
#        'crs_elapsed_time', 'actual_elapsed_time', 'air_time', 'distance',
#        'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay',
#        'late_aircraft_delay', 'first_dep_time', 'total_add_gtime',
#        'longest_add_gtime'],
#       dtype='object')

# %%
flights_df.shape
# Out:
# (15927485, 33)

# %% [markdown]
# #### Group states into four regions

# %%
regions = {
    'WA': 'West',
    'OR': 'West',
    'ID': 'West',
    'MT': 'West',
    'WY': 'West',
    'CA': 'West',
    'NV': 'West',
    'UT': 'West',
    'AZ': 'West',
    'CO': 'West',
    'NM': 'West',
    'HI': 'West',
    'AK': 'West',
    'TT': 'West',
    
    'ND': 'Midwest',
    'SD': 'Midwest',
    'NE': 'Midwest',
    'KS': 'Midwest',
    'MN': 'Midwest',
    'IA': 'Midwest',
    'MO': 'Midwest',
    'WI': 'Midwest',
    'IL': 'Midwest',
    'IN': 'Midwest',
    'MI': 'Midwest',
    'OH': 'Midwest',

    'OK': 'South',
    'TX': 'South',
    'AR': 'South',
    'LA': 'South',
    'MS': 'South',
    'AL': 'South',
    'TN': 'South',
    'KY': 'South',
    'WV': 'South',
    'DC': 'South',
    'VA': 'South',
    'DE': 'South',
    'MD': 'South',
    'NC': 'South',
    'SC': 'South',
    'GA': 'South',
    'FL': 'South',
    'PR': 'South',
    'VI': 'South',

    'PA': 'Northeast',
    'NY': 'Northeast',
    'VT': 'Northeast',
    'ME': 'Northeast',
    'NH': 'Northeast',
    'MA': 'Northeast',
    'CT': 'Northeast',
    'RI': 'Northeast',
    'NJ': 'Northeast'

    }

# %% [markdown]
# ## Create new columns

# %% [markdown]
# ### 1. Split cities and states. Group states into four regions - 'West', 'Midwest', 'Northeast', 'South'

# %%
# Split City and State 
flights_df[['origin_city', 'origin_state']] = flights_df['origin_city_name'].str.split(", ",expand=True,) 
flights_df[['dest_city', 'dest_state']] = flights_df['dest_city_name'].str.split(", ",expand=True,)

# %%
flights_df=flights_df.replace({"origin_state": regions})
flights_df=flights_df.replace({"dest_state": regions})

# %%
# Rename origin_state/dest_state columns to origin_region/dest_region
flights_df = flights_df.rename(columns={'origin_state': 'origin_region', 'dest_state': 'dest_region'})

# %% [markdown]
# ### 2. Extract day, month, and year

# %%
flights_df['day'] = pd.DatetimeIndex(flights_df['fl_date']).day
flights_df['month'] = pd.DatetimeIndex(flights_df['fl_date']).month
flights_df['year'] = pd.DatetimeIndex(flights_df['fl_date']).year

# %% [markdown]
# ### 3. Four categories of flight time - 'Morning', 'Afternon', 'Evening', and 'Night'

# %%
# Converting time into 24 hours
flights_df['crs_arr_hrs'] = (flights_df['crs_arr_time']/100).astype(int)
flights_df['crs_dep_hrs'] = (flights_df['crs_dep_time']/100).astype(int)

# %%
ctg = []
for i in flights_df['crs_dep_hrs']:
    if (i>=5) and (i<12):
        ctg.append('Morning')
    elif (i>=12) and (i<16):
        ctg.append('Afternoon')
    elif (i>=16) and (i<=22):
        ctg.append('Evening')
    elif (i>22) or (i<5):
        ctg.append('Night')

flights_df['dep_hrs_ctg'] = ctg

# %%
# Four categories of flight time - 'Morning', 'Afternon', 'Evening', and 'Night' for crs_arr_hrs

ctg = []
for i in flights_df['crs_arr_hrs']:
    if (i>=5) and (i<12):
        ctg.append('Morning')
    elif (i>=12) and (i<16):
        ctg.append('Afternoon')
    elif (i>=16) and (i<=22):
        ctg.append('Evening')
    elif (i>22) or (i<5):
        ctg.append('Night')

flights_df['arr_hrs_ctg'] = ctg

# %% [markdown]
# ### 4. Day of the week (where Monday is 0)

# %%
flights_df['fl_date'][0]
# Out:
# '2019-08-22'

# %%
# Conver object to datatime format
flights_df['fl_date'] = pd.to_datetime(flights_df['fl_date'])

# %%
# Convert datetime column/series to day of the week
flights_df['day_of_week'] = flights_df['fl_date'].dt.weekday

# %%
# Replace day numbers with day names
flights_df = flights_df.replace({'day_of_week' : { 
                                                    0 : 'Monday', 
                                                    1 : 'Tuesday', 
                                                    2 : 'Wednesday', 
                                                    3: 'Thursday', 
                                                    4: 'Friday', 
                                                    5: 'Saturday', 
                                                    6: 'Sunday'}})

# %%
# To get the name of the day of the week 
# print(calendar.day_name[my_date.weekday()])

# %%
flights_df['fl_date'].unique()
# Out:
# array(['2019-08-22T00:00:00.000000000', '2019-08-23T00:00:00.000000000',
#        '2019-08-24T00:00:00.000000000', '2019-08-25T00:00:00.000000000',
#        '2019-08-26T00:00:00.000000000', '2019-08-27T00:00:00.000000000',
#        '2019-08-30T00:00:00.000000000', '2019-08-28T00:00:00.000000000',
#        '2019-08-29T00:00:00.000000000', '2019-08-31T00:00:00.000000000',
#        '2019-02-01T00:00:00.000000000', '2019-02-02T00:00:00.000000000',
#        '2019-02-06T00:00:00.000000000', '2019-02-03T00:00:00.000000000',
#        '2019-02-04T00:00:00.000000000', '2019-02-05T00:00:00.000000000',
#        '2019-02-07T00:00:00.000000000', '2019-02-09T00:00:00.000000000',
#        '2019-02-10T00:00:00.000000000', '2019-02-11T00:00:00.000000000',
#        '2019-02-12T00:00:00.000000000', '2019-02-08T00:00:00.000000000',
#        '2019-02-13T00:00:00.000000000', '2019-02-14T00:00:00.000000000',
#        '2019-02-17T00:00:00.000000000', '2019-02-18T00:00:00.000000000',
#        '2019-02-15T00:00:00.000000000', '2019-02-16T00:00:00.000000000',
#        '2019-02-19T00:00:00.000000000', '2019-02-20T00:00:00.000000000',
#        '2019-02-21T00:00:00.000000000', '2019-02-22T00:00:00.000000000',
#        '2019-02-23T00:00:00.000000000', '2019-02-24T00:00:00.000000000',
#        '2019-02-25T00:00:00.000000000', '2019-02-26T00:00:00.000000000',
#        '2019-02-27T00:00:00.000000000', '2019-02-28T00:00:00.000000000',
#        '2018-06-01T00:00:00.000000000', '2018-06-04T00:00:00.000000000',
#        '2018-06-07T00:00:00.000000000', '2018-06-02T00:00:00.000000000',
#        '2018-06-06T00:00:00.000000000', '2018-06-03T00:00:00.000000000',
#        '2018-06-05T00:00:00.000000000', '2018-06-08T00:00:00.000000000',
#        '2018-06-10T00:00:00.000000000', '2018-06-09T00:00:00.000000000',
#        '2018-06-11T00:00:00.000000000', '2018-06-12T00:00:00.000000000',
#        '2018-06-14T00:00:00.000000000', '2018-06-15T00:00:00.000000000',
#        '2018-06-16T00:00:00.000000000', '2018-06-17T00:00:00.000000000',
#        '2018-06-13T00:00:00.000000000', '2018-06-18T00:00:00.000000000',
#        '2018-06-19T00:00:00.000000000', '2018-06-20T00:00:00.000000000',
#        '2018-06-21T00:00:00.000000000', '2018-06-22T00:00:00.000000000',
#        '2018-06-23T00:00:00.000000000', '2018-06-24T00:00:00.000000000',
#        '2018-06-26T00:00:00.000000000', '2018-06-25T00:00:00.000000000',
#        '2018-06-27T00:00:00.000000000', '2018-06-28T00:00:00.000000000',
#        '2018-06-29T00:00:00.000000000', '2019-11-01T00:00:00.000000000',
#        '2018-06-30T00:00:00.000000000', '2019-11-02T00:00:00.000000000',
#        '2019-11-03T00:00:00.000000000', '2019-11-04T00:00:00.000000000',
#        '2019-11-05T00:00:00.000000000', '2019-11-06T00:00:00.000000000',
#        '2019-11-07T00:00:00.000000000', '2019-11-08T00:00:00.000000000',
#        '2019-11-11T00:00:00.000000000', '2019-11-13T00:00:00.000000000',
#        '2019-11-09T00:00:00.000000000', '2019-11-10T00:00:00.000000000',
#        '2019-11-12T00:00:00.000000000', '2019-11-14T00:00:00.000000000',
#        '2019-11-15T00:00:00.000000000', '2019-11-16T00:00:00.000000000',
#        '2019-11-17T00:00:00.000000000', '2019-11-18T00:00:00.000000000',
#        '2019-11-19T00:00:00.000000000', '2019-11-20T00:00:00.000000000',
#        '2019-11-21T00:00:00.000000000', '2019-11-22T00:00:00.000000000',
#        '2019-11-23T00:00:00.000000000', '2019-11-24T00:00:00.000000000',
#        '2019-11-26T00:00:00.000000000', '2019-11-25T00:00:00.000000000',
#        '2019-11-27T00:00:00.000000000', '2019-11-28T00:00:00.000000000',
#        '2019-11-29T00:00:00.000000000', '2019-11-30T00:00:00.000000000',
#        '2018-12-02T00:00:00.000000000', '2018-12-05T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-03T00:00:00.000000000',
#        '2018-12-04T00:00:00.000000000', '2018-12-06T00:00:00.000000000',
#        '2018-12-09T00:00:00.000000000', '2018-12-10T00:00:00.000000000',
#        '2018-12-07T00:00:00.000000000', '2018-12-08T00:00:00.000000000',
#        '2018-12-11T00:00:00.000000000', '2018-12-16T00:00:00.000000000',
#        '2018-12-12T00:00:00.000000000', '2018-12-13T00:00:00.000000000',
#        '2018-12-14T00:00:00.000000000', '2018-12-15T00:00:00.000000000',
#        '2018-12-17T00:00:00.000000000', '2018-12-19T00:00:00.000000000',
#        '2018-12-21T00:00:00.000000000', '2018-12-18T00:00:00.000000000',
#        '2018-12-20T00:00:00.000000000', '2018-12-22T00:00:00.000000000',
#        '2018-12-27T00:00:00.000000000', '2018-12-23T00:00:00.000000000',
#        '2018-12-26T00:00:00.000000000', '2018-12-28T00:00:00.000000000',
#        '2018-12-24T00:00:00.000000000', '2018-12-25T00:00:00.000000000',
#        '2018-10-02T00:00:00.000000000', '2018-10-01T00:00:00.000000000',
#        '2018-12-29T00:00:00.000000000', '2018-12-30T00:00:00.000000000',
#        '2018-12-31T00:00:00.000000000', '2018-10-03T00:00:00.000000000',
#        '2018-10-06T00:00:00.000000000', '2018-10-04T00:00:00.000000000',
#        '2018-10-05T00:00:00.000000000', '2018-10-07T00:00:00.000000000',
#        '2018-10-08T00:00:00.000000000', '2018-10-09T00:00:00.000000000',
#        '2018-10-11T00:00:00.000000000', '2018-10-13T00:00:00.000000000',
#        '2018-10-10T00:00:00.000000000', '2018-10-12T00:00:00.000000000',
#        '2018-10-14T00:00:00.000000000', '2018-10-17T00:00:00.000000000',
#        '2018-10-15T00:00:00.000000000', '2018-10-16T00:00:00.000000000',
#        '2018-10-18T00:00:00.000000000', '2018-10-19T00:00:00.000000000',
#        '2018-10-20T00:00:00.000000000', '2018-10-21T00:00:00.000000000',
#        '2018-10-22T00:00:00.000000000', '2018-10-23T00:00:00.000000000',
#        '2018-10-24T00:00:00.000000000', '2018-10-25T00:00:00.000000000',
#        '2018-10-26T00:00:00.000000000', '2018-10-27T00:00:00.000000000',
#        '2018-10-28T00:00:00.000000000', '2018-10-29T00:00:00.000000000',
#        '2018-10-30T00:00:00.000000000', '2019-12-01T00:00:00.000000000',
#        '2019-12-02T00:00:00.000000000', '2019-12-03T00:00:00.000000000',
#        '2018-10-31T00:00:00.000000000', '2019-12-04T00:00:00.000000000',
#        '2019-12-07T00:00:00.000000000', '2019-12-08T00:00:00.000000000',
#        '2019-12-05T00:00:00.000000000', '2019-12-09T00:00:00.000000000',
#        '2019-12-06T00:00:00.000000000', '2019-12-10T00:00:00.000000000',
#        '2019-12-11T00:00:00.000000000', '2019-12-13T00:00:00.000000000',
#        '2019-12-12T00:00:00.000000000', '2019-12-14T00:00:00.000000000',
#        '2019-12-15T00:00:00.000000000', '2019-12-16T00:00:00.000000000',
#        '2019-12-17T00:00:00.000000000', '2019-12-18T00:00:00.000000000',
#        '2019-12-19T00:00:00.000000000', '2019-12-20T00:00:00.000000000',
#        '2019-12-21T00:00:00.000000000', '2019-12-23T00:00:00.000000000',
#        '2019-12-24T00:00:00.000000000', '2019-12-22T00:00:00.000000000',
#        '2019-12-25T00:00:00.000000000', '2019-12-26T00:00:00.000000000',
#        '2019-12-28T00:00:00.000000000', '2019-12-30T00:00:00.000000000',
#        '2019-09-01T00:00:00.000000000', '2019-12-27T00:00:00.000000000',
#        '2019-12-29T00:00:00.000000000', '2019-12-31T00:00:00.000000000',
#        '2019-09-02T00:00:00.000000000', '2019-09-03T00:00:00.000000000',
#        '2019-09-04T00:00:00.000000000', '2019-09-05T00:00:00.000000000',
#        '2019-09-06T00:00:00.000000000', '2019-09-07T00:00:00.000000000',
#        '2019-09-09T00:00:00.000000000', '2019-09-08T00:00:00.000000000',
#        '2019-09-10T00:00:00.000000000', '2019-09-11T00:00:00.000000000',
#        '2019-09-12T00:00:00.000000000', '2019-09-13T00:00:00.000000000',
#        '2019-09-14T00:00:00.000000000', '2019-09-15T00:00:00.000000000',
#        '2019-09-16T00:00:00.000000000', '2019-09-17T00:00:00.000000000',
#        '2019-09-18T00:00:00.000000000', '2019-09-19T00:00:00.000000000',
#        '2019-09-20T00:00:00.000000000', '2019-09-21T00:00:00.000000000',
#        '2019-09-22T00:00:00.000000000', '2019-09-23T00:00:00.000000000',
#        '2019-09-27T00:00:00.000000000', '2019-09-24T00:00:00.000000000',
#        '2019-09-25T00:00:00.000000000', '2019-09-26T00:00:00.000000000',
#        '2019-09-28T00:00:00.000000000', '2019-01-03T00:00:00.000000000',
#        '2019-09-29T00:00:00.000000000', '2019-09-30T00:00:00.000000000',
#        '2019-01-01T00:00:00.000000000', '2019-01-02T00:00:00.000000000',
#        '2019-01-06T00:00:00.000000000', '2019-01-07T00:00:00.000000000',
#        '2019-01-09T00:00:00.000000000', '2019-01-04T00:00:00.000000000',
#        '2019-01-05T00:00:00.000000000', '2019-01-08T00:00:00.000000000',
#        '2019-01-10T00:00:00.000000000', '2019-01-12T00:00:00.000000000',
#        '2019-01-13T00:00:00.000000000', '2019-01-11T00:00:00.000000000',
#        '2019-01-14T00:00:00.000000000', '2019-01-15T00:00:00.000000000',
#        '2019-01-16T00:00:00.000000000', '2019-01-18T00:00:00.000000000',
#        '2019-01-19T00:00:00.000000000', '2019-01-17T00:00:00.000000000',
#        '2019-01-20T00:00:00.000000000', '2019-01-21T00:00:00.000000000',
#        '2019-01-22T00:00:00.000000000', '2019-01-24T00:00:00.000000000',
#        '2019-01-26T00:00:00.000000000', '2019-01-23T00:00:00.000000000',
#        '2019-01-25T00:00:00.000000000', '2019-01-27T00:00:00.000000000',
#        '2019-01-28T00:00:00.000000000', '2019-01-29T00:00:00.000000000',
#        '2019-01-30T00:00:00.000000000', '2019-01-31T00:00:00.000000000',
#        '2018-05-01T00:00:00.000000000', '2018-05-02T00:00:00.000000000',
#        '2018-05-03T00:00:00.000000000', '2018-05-04T00:00:00.000000000',
#        '2018-05-05T00:00:00.000000000', '2018-05-06T00:00:00.000000000',
#        '2018-05-07T00:00:00.000000000', '2018-05-09T00:00:00.000000000',
#        '2018-05-10T00:00:00.000000000', '2018-05-08T00:00:00.000000000',
#        '2018-05-11T00:00:00.000000000', '2018-05-12T00:00:00.000000000',
#        '2018-05-13T00:00:00.000000000', '2018-05-14T00:00:00.000000000',
#        '2018-05-15T00:00:00.000000000', '2018-05-17T00:00:00.000000000',
#        '2018-05-16T00:00:00.000000000', '2018-05-18T00:00:00.000000000',
#        '2018-05-19T00:00:00.000000000', '2018-05-20T00:00:00.000000000',
#        '2018-05-21T00:00:00.000000000', '2018-05-22T00:00:00.000000000',
#        '2018-05-23T00:00:00.000000000', '2018-05-25T00:00:00.000000000',
#        '2018-05-24T00:00:00.000000000', '2018-05-26T00:00:00.000000000',
#        '2018-05-27T00:00:00.000000000', '2018-05-28T00:00:00.000000000',
#        '2018-05-29T00:00:00.000000000', '2018-05-31T00:00:00.000000000',
#        '2018-02-04T00:00:00.000000000', '2018-05-30T00:00:00.000000000',
#        '2018-02-01T00:00:00.000000000', '2018-02-02T00:00:00.000000000',
#        '2018-02-03T00:00:00.000000000', '2018-02-05T00:00:00.000000000',
#        '2018-02-07T00:00:00.000000000', '2018-02-09T00:00:00.000000000',
#        '2018-02-06T00:00:00.000000000', '2018-02-08T00:00:00.000000000',
#        '2018-02-10T00:00:00.000000000', '2018-02-11T00:00:00.000000000',
#        '2018-02-12T00:00:00.000000000', '2018-02-15T00:00:00.000000000',
#        '2018-02-14T00:00:00.000000000', '2018-02-13T00:00:00.000000000',
#        '2018-02-16T00:00:00.000000000', '2018-02-17T00:00:00.000000000',
#        '2018-02-18T00:00:00.000000000', '2018-02-19T00:00:00.000000000',
#        '2018-02-20T00:00:00.000000000', '2018-02-21T00:00:00.000000000',
#        '2018-02-22T00:00:00.000000000', '2018-02-24T00:00:00.000000000',
#        '2018-02-25T00:00:00.000000000', '2018-02-27T00:00:00.000000000',
#        '2018-02-26T00:00:00.000000000', '2018-02-23T00:00:00.000000000',
#        '2018-09-01T00:00:00.000000000', '2018-09-03T00:00:00.000000000',
#        '2018-02-28T00:00:00.000000000', '2018-09-02T00:00:00.000000000',
#        '2018-09-04T00:00:00.000000000', '2018-09-05T00:00:00.000000000',
#        '2018-09-06T00:00:00.000000000', '2018-09-07T00:00:00.000000000',
#        '2018-09-08T00:00:00.000000000', '2018-09-09T00:00:00.000000000',
#        '2018-09-10T00:00:00.000000000', '2018-09-11T00:00:00.000000000',
#        '2018-09-12T00:00:00.000000000', '2018-09-13T00:00:00.000000000',
#        '2018-09-14T00:00:00.000000000', '2018-09-15T00:00:00.000000000',
#        '2018-09-16T00:00:00.000000000', '2018-09-17T00:00:00.000000000',
#        '2018-09-18T00:00:00.000000000', '2018-09-21T00:00:00.000000000',
#        '2018-09-22T00:00:00.000000000', '2018-09-19T00:00:00.000000000',
#        '2018-09-20T00:00:00.000000000', '2018-09-23T00:00:00.000000000',
#        '2018-09-26T00:00:00.000000000', '2018-09-24T00:00:00.000000000',
#        '2018-09-25T00:00:00.000000000', '2018-09-27T00:00:00.000000000',
#        '2018-09-30T00:00:00.000000000', '2018-04-02T00:00:00.000000000',
#        '2018-04-01T00:00:00.000000000', '2018-04-03T00:00:00.000000000',
#        '2018-09-28T00:00:00.000000000', '2018-09-29T00:00:00.000000000',
#        '2018-04-05T00:00:00.000000000', '2018-04-04T00:00:00.000000000',
#        '2018-04-06T00:00:00.000000000', '2018-04-07T00:00:00.000000000',
#        '2018-04-08T00:00:00.000000000', '2018-04-10T00:00:00.000000000',
#        '2018-04-09T00:00:00.000000000', '2018-04-11T00:00:00.000000000',
#        '2018-04-12T00:00:00.000000000', '2018-04-13T00:00:00.000000000',
#        '2018-04-14T00:00:00.000000000', '2018-04-15T00:00:00.000000000',
#        '2018-04-17T00:00:00.000000000', '2018-04-18T00:00:00.000000000',
#        '2018-04-16T00:00:00.000000000', '2018-04-19T00:00:00.000000000',
#        '2018-04-20T00:00:00.000000000', '2018-04-21T00:00:00.000000000',
#        '2018-04-22T00:00:00.000000000', '2018-04-23T00:00:00.000000000',
#        '2018-04-24T00:00:00.000000000', '2018-04-25T00:00:00.000000000',
#        '2018-04-26T00:00:00.000000000', '2018-04-27T00:00:00.000000000',
#        '2018-04-28T00:00:00.000000000', '2018-04-29T00:00:00.000000000',
#        '2018-04-30T00:00:00.000000000', '2018-07-02T00:00:00.000000000',
#        '2018-07-03T00:00:00.000000000', '2018-07-01T00:00:00.000000000',
#        '2018-07-04T00:00:00.000000000', '2018-07-05T00:00:00.000000000',
#        '2018-07-06T00:00:00.000000000', '2018-07-10T00:00:00.000000000',
#        '2018-07-09T00:00:00.000000000', '2018-07-07T00:00:00.000000000',
#        '2018-07-08T00:00:00.000000000', '2018-07-11T00:00:00.000000000',
#        '2018-07-12T00:00:00.000000000', '2018-07-14T00:00:00.000000000',
#        '2018-07-15T00:00:00.000000000', '2018-07-13T00:00:00.000000000',
#        '2018-07-16T00:00:00.000000000', '2018-07-17T00:00:00.000000000',
#        '2018-07-20T00:00:00.000000000', '2018-07-21T00:00:00.000000000',
#        '2018-07-18T00:00:00.000000000', '2018-07-19T00:00:00.000000000',
#        '2018-07-22T00:00:00.000000000', '2018-07-23T00:00:00.000000000',
#        '2018-07-24T00:00:00.000000000', '2018-07-25T00:00:00.000000000',
#        '2018-07-26T00:00:00.000000000', '2018-07-27T00:00:00.000000000',
#        '2018-07-29T00:00:00.000000000', '2018-07-30T00:00:00.000000000',
#        '2018-07-28T00:00:00.000000000', '2018-07-31T00:00:00.000000000',
#        '2019-05-01T00:00:00.000000000', '2019-05-02T00:00:00.000000000',
#        '2019-05-03T00:00:00.000000000', '2019-05-04T00:00:00.000000000',
#        '2019-05-05T00:00:00.000000000', '2019-05-06T00:00:00.000000000',
#        '2019-05-08T00:00:00.000000000', '2019-05-07T00:00:00.000000000',
#        '2019-05-09T00:00:00.000000000', '2019-05-11T00:00:00.000000000',
#        '2019-05-10T00:00:00.000000000', '2019-05-14T00:00:00.000000000',
#        '2019-05-15T00:00:00.000000000', '2019-05-16T00:00:00.000000000',
#        '2019-05-12T00:00:00.000000000', '2019-05-13T00:00:00.000000000',
#        '2019-05-17T00:00:00.000000000', '2019-05-18T00:00:00.000000000',
#        '2019-05-19T00:00:00.000000000', '2019-05-20T00:00:00.000000000',
#        '2019-05-21T00:00:00.000000000', '2019-05-22T00:00:00.000000000',
#        '2019-05-23T00:00:00.000000000', '2019-05-26T00:00:00.000000000',
#        '2019-05-27T00:00:00.000000000', '2019-05-24T00:00:00.000000000',
#        '2019-05-25T00:00:00.000000000', '2019-05-28T00:00:00.000000000',
#        '2019-05-29T00:00:00.000000000', '2019-05-30T00:00:00.000000000',
#        '2019-05-31T00:00:00.000000000', '2019-04-01T00:00:00.000000000',
#        '2019-04-02T00:00:00.000000000', '2019-04-03T00:00:00.000000000',
#        '2019-04-06T00:00:00.000000000', '2019-04-07T00:00:00.000000000',
#        '2019-04-04T00:00:00.000000000', '2019-04-05T00:00:00.000000000',
#        '2019-04-09T00:00:00.000000000', '2019-04-10T00:00:00.000000000',
#        '2019-04-11T00:00:00.000000000', '2019-04-08T00:00:00.000000000',
#        '2019-04-12T00:00:00.000000000', '2019-04-13T00:00:00.000000000',
#        '2019-04-14T00:00:00.000000000', '2019-04-15T00:00:00.000000000',
#        '2019-04-16T00:00:00.000000000', '2019-04-17T00:00:00.000000000',
#        '2019-04-18T00:00:00.000000000', '2019-04-19T00:00:00.000000000',
#        '2019-04-21T00:00:00.000000000', '2019-04-20T00:00:00.000000000',
#        '2019-04-22T00:00:00.000000000', '2019-04-23T00:00:00.000000000',
#        '2019-04-24T00:00:00.000000000', '2019-04-25T00:00:00.000000000',
#        '2019-04-26T00:00:00.000000000', '2019-04-27T00:00:00.000000000',
#        '2019-04-28T00:00:00.000000000', '2019-04-29T00:00:00.000000000',
#        '2019-04-30T00:00:00.000000000', '2019-03-01T00:00:00.000000000',
#        '2019-03-02T00:00:00.000000000', '2019-03-03T00:00:00.000000000',
#        '2019-03-04T00:00:00.000000000', '2019-03-06T00:00:00.000000000',
#        '2019-03-08T00:00:00.000000000', '2019-03-05T00:00:00.000000000',
#        '2019-03-07T00:00:00.000000000', '2019-03-09T00:00:00.000000000',
#        '2019-03-12T00:00:00.000000000', '2019-03-10T00:00:00.000000000',
#        '2019-03-13T00:00:00.000000000', '2019-03-14T00:00:00.000000000',
#        '2019-03-11T00:00:00.000000000', '2019-03-15T00:00:00.000000000',
#        '2019-03-16T00:00:00.000000000', '2019-03-19T00:00:00.000000000',
#        '2019-03-20T00:00:00.000000000', '2019-03-17T00:00:00.000000000',
#        '2019-03-18T00:00:00.000000000', '2019-03-24T00:00:00.000000000',
#        '2019-03-21T00:00:00.000000000', '2019-03-22T00:00:00.000000000',
#        '2019-03-23T00:00:00.000000000', '2019-03-25T00:00:00.000000000',
#        '2019-03-26T00:00:00.000000000', '2019-03-27T00:00:00.000000000',
#        '2019-03-28T00:00:00.000000000', '2019-03-31T00:00:00.000000000',
#        '2019-03-29T00:00:00.000000000', '2019-03-30T00:00:00.000000000',
#        '2019-07-02T00:00:00.000000000', '2019-07-01T00:00:00.000000000',
#        '2019-07-04T00:00:00.000000000', '2019-07-03T00:00:00.000000000',
#        '2019-07-05T00:00:00.000000000', '2019-07-06T00:00:00.000000000',
#        '2019-07-10T00:00:00.000000000', '2019-07-07T00:00:00.000000000',
#        '2019-07-08T00:00:00.000000000', '2019-07-09T00:00:00.000000000',
#        '2019-07-11T00:00:00.000000000', '2019-07-13T00:00:00.000000000',
#        '2019-07-14T00:00:00.000000000', '2019-07-15T00:00:00.000000000',
#        '2019-07-12T00:00:00.000000000', '2019-07-16T00:00:00.000000000',
#        '2019-07-17T00:00:00.000000000', '2019-07-18T00:00:00.000000000',
#        '2019-07-19T00:00:00.000000000', '2019-07-20T00:00:00.000000000',
#        '2019-07-21T00:00:00.000000000', '2019-07-22T00:00:00.000000000',
#        '2019-07-23T00:00:00.000000000', '2019-07-24T00:00:00.000000000',
#        '2019-07-25T00:00:00.000000000', '2019-07-29T00:00:00.000000000',
#        '2019-07-30T00:00:00.000000000', '2019-07-26T00:00:00.000000000',
#        '2019-07-27T00:00:00.000000000', '2019-07-28T00:00:00.000000000',
#        '2019-07-31T00:00:00.000000000', '2018-01-01T00:00:00.000000000',
#        '2018-01-02T00:00:00.000000000', '2018-01-03T00:00:00.000000000',
#        '2018-01-04T00:00:00.000000000', '2018-01-05T00:00:00.000000000',
#        '2018-01-06T00:00:00.000000000', '2018-01-07T00:00:00.000000000',
#        '2018-01-08T00:00:00.000000000', '2018-01-09T00:00:00.000000000',
#        '2018-01-10T00:00:00.000000000', '2018-01-11T00:00:00.000000000',
#        '2018-01-12T00:00:00.000000000', '2018-01-13T00:00:00.000000000',
#        '2018-01-14T00:00:00.000000000', '2018-01-15T00:00:00.000000000',
#        '2018-01-16T00:00:00.000000000', '2018-01-22T00:00:00.000000000',
#        '2018-01-17T00:00:00.000000000', '2018-01-18T00:00:00.000000000',
#        '2018-01-19T00:00:00.000000000', '2018-01-20T00:00:00.000000000',
#        '2018-01-21T00:00:00.000000000', '2018-01-23T00:00:00.000000000',
#        '2018-01-24T00:00:00.000000000', '2018-01-25T00:00:00.000000000',
#        '2018-01-27T00:00:00.000000000', '2018-01-26T00:00:00.000000000',
#        '2018-01-28T00:00:00.000000000', '2018-01-29T00:00:00.000000000',
#        '2018-01-30T00:00:00.000000000', '2018-01-31T00:00:00.000000000',
#        '2018-08-01T00:00:00.000000000', '2018-08-02T00:00:00.000000000',
#        '2018-08-03T00:00:00.000000000', '2018-08-04T00:00:00.000000000',
#        '2018-08-05T00:00:00.000000000', '2018-08-06T00:00:00.000000000',
#        '2018-08-07T00:00:00.000000000', '2018-08-08T00:00:00.000000000',
#        '2018-08-09T00:00:00.000000000', '2018-08-10T00:00:00.000000000',
#        '2018-08-11T00:00:00.000000000', '2018-08-12T00:00:00.000000000',
#        '2018-08-13T00:00:00.000000000', '2018-08-14T00:00:00.000000000',
#        '2018-08-15T00:00:00.000000000', '2018-08-16T00:00:00.000000000',
#        '2018-08-17T00:00:00.000000000', '2018-08-19T00:00:00.000000000',
#        '2018-08-18T00:00:00.000000000', '2018-08-20T00:00:00.000000000',
#        '2018-08-21T00:00:00.000000000', '2018-08-23T00:00:00.000000000',
#        '2018-08-22T00:00:00.000000000', '2018-08-24T00:00:00.000000000',
#        '2018-08-29T00:00:00.000000000', '2018-08-25T00:00:00.000000000',
#        '2018-08-26T00:00:00.000000000', '2018-08-27T00:00:00.000000000',
#        '2018-08-28T00:00:00.000000000', '2018-08-30T00:00:00.000000000',
#        '2019-10-03T00:00:00.000000000', '2018-08-31T00:00:00.000000000',
#        '2019-10-01T00:00:00.000000000', '2019-10-02T00:00:00.000000000',
#        '2019-10-04T00:00:00.000000000', '2019-10-05T00:00:00.000000000',
#        '2019-10-06T00:00:00.000000000', '2019-10-07T00:00:00.000000000',
#        '2019-10-08T00:00:00.000000000', '2019-10-09T00:00:00.000000000',
#        '2019-10-10T00:00:00.000000000', '2019-10-11T00:00:00.000000000',
#        '2019-10-13T00:00:00.000000000', '2019-10-12T00:00:00.000000000',
#        '2019-10-14T00:00:00.000000000', '2019-10-15T00:00:00.000000000',
#        '2019-10-17T00:00:00.000000000', '2019-10-18T00:00:00.000000000',
#        '2019-10-16T00:00:00.000000000', '2019-10-19T00:00:00.000000000',
#        '2019-10-20T00:00:00.000000000', '2019-10-22T00:00:00.000000000',
#        '2019-10-24T00:00:00.000000000', '2019-10-25T00:00:00.000000000',
#        '2019-10-21T00:00:00.000000000', '2019-10-23T00:00:00.000000000',
#        '2019-10-29T00:00:00.000000000', '2019-10-30T00:00:00.000000000',
#        '2019-10-31T00:00:00.000000000', '2019-10-26T00:00:00.000000000',
#        '2019-10-27T00:00:00.000000000', '2019-10-28T00:00:00.000000000',
#        '2018-11-01T00:00:00.000000000', '2018-11-02T00:00:00.000000000',
#        '2018-11-03T00:00:00.000000000', '2018-11-04T00:00:00.000000000',
#        '2018-11-05T00:00:00.000000000', '2018-11-06T00:00:00.000000000',
#        '2018-11-07T00:00:00.000000000', '2018-11-11T00:00:00.000000000',
#        '2018-11-08T00:00:00.000000000', '2018-11-09T00:00:00.000000000',
#        '2018-11-10T00:00:00.000000000', '2018-11-15T00:00:00.000000000',
#        '2018-11-12T00:00:00.000000000', '2018-11-14T00:00:00.000000000',
#        '2018-11-16T00:00:00.000000000', '2018-11-13T00:00:00.000000000',
#        '2018-11-17T00:00:00.000000000', '2018-11-18T00:00:00.000000000',
#        '2018-11-19T00:00:00.000000000', '2018-11-20T00:00:00.000000000',
#        '2018-11-21T00:00:00.000000000', '2018-11-22T00:00:00.000000000',
#        '2018-11-25T00:00:00.000000000', '2018-11-26T00:00:00.000000000',
#        '2018-11-23T00:00:00.000000000', '2018-11-24T00:00:00.000000000',
#        '2018-11-27T00:00:00.000000000', '2018-11-28T00:00:00.000000000',
#        '2019-06-01T00:00:00.000000000', '2019-06-02T00:00:00.000000000',
#        '2018-11-29T00:00:00.000000000', '2018-11-30T00:00:00.000000000',
#        '2019-06-03T00:00:00.000000000', '2019-06-05T00:00:00.000000000',
#        '2019-06-07T00:00:00.000000000', '2019-06-08T00:00:00.000000000',
#        '2019-06-04T00:00:00.000000000', '2019-06-06T00:00:00.000000000',
#        '2019-06-09T00:00:00.000000000', '2019-06-10T00:00:00.000000000',
#        '2019-06-13T00:00:00.000000000', '2019-06-11T00:00:00.000000000',
#        '2019-06-12T00:00:00.000000000', '2019-06-14T00:00:00.000000000',
#        '2019-06-16T00:00:00.000000000', '2019-06-17T00:00:00.000000000',
#        '2019-06-18T00:00:00.000000000', '2019-06-15T00:00:00.000000000',
#        '2019-06-19T00:00:00.000000000', '2019-06-20T00:00:00.000000000',
#        '2019-06-21T00:00:00.000000000', '2019-06-22T00:00:00.000000000',
#        '2019-06-23T00:00:00.000000000', '2019-06-24T00:00:00.000000000',
#        '2019-06-26T00:00:00.000000000', '2019-06-27T00:00:00.000000000',
#        '2019-06-25T00:00:00.000000000', '2019-06-28T00:00:00.000000000',
#        '2019-06-29T00:00:00.000000000', '2019-06-30T00:00:00.000000000',
#        '2018-03-02T00:00:00.000000000', '2018-03-01T00:00:00.000000000',
#        '2018-03-03T00:00:00.000000000', '2018-03-04T00:00:00.000000000',
#        '2018-03-06T00:00:00.000000000', '2018-03-07T00:00:00.000000000',
#        '2018-03-05T00:00:00.000000000', '2018-03-08T00:00:00.000000000',
#        '2018-03-09T00:00:00.000000000', '2018-03-10T00:00:00.000000000',
#        '2018-03-12T00:00:00.000000000', '2018-03-13T00:00:00.000000000',
#        '2018-03-11T00:00:00.000000000', '2018-03-14T00:00:00.000000000',
#        '2018-03-15T00:00:00.000000000', '2018-03-16T00:00:00.000000000',
#        '2018-03-19T00:00:00.000000000', '2018-03-20T00:00:00.000000000',
#        '2018-03-21T00:00:00.000000000', '2018-03-17T00:00:00.000000000',
#        '2018-03-18T00:00:00.000000000', '2018-03-22T00:00:00.000000000',
#        '2018-03-24T00:00:00.000000000', '2018-03-23T00:00:00.000000000',
#        '2018-03-25T00:00:00.000000000', '2018-03-26T00:00:00.000000000',
#        '2018-03-28T00:00:00.000000000', '2018-03-29T00:00:00.000000000',
#        '2018-03-27T00:00:00.000000000', '2018-03-30T00:00:00.000000000',
#        '2018-03-31T00:00:00.000000000', '2019-08-01T00:00:00.000000000',
#        '2019-08-02T00:00:00.000000000', '2019-08-03T00:00:00.000000000',
#        '2019-08-04T00:00:00.000000000', '2019-08-05T00:00:00.000000000',
#        '2019-08-06T00:00:00.000000000', '2019-08-07T00:00:00.000000000',
#        '2019-08-08T00:00:00.000000000', '2019-08-10T00:00:00.000000000',
#        '2019-08-09T00:00:00.000000000', '2019-08-11T00:00:00.000000000',
#        '2019-08-12T00:00:00.000000000', '2019-08-13T00:00:00.000000000',
#        '2019-08-14T00:00:00.000000000', '2019-08-15T00:00:00.000000000',
#        '2019-08-16T00:00:00.000000000', '2019-08-18T00:00:00.000000000',
#        '2019-08-19T00:00:00.000000000', '2019-08-21T00:00:00.000000000',
#        '2019-08-20T00:00:00.000000000', '2019-08-17T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %% [markdown]
# ### 5. Day of year

# %%
# Convert datetime column/series to year
flights_df['day_of_year'] = flights_df['fl_date'].dt.day_of_year

# %% [markdown]
# ### 6. Week of year

# %%
# Convert datetime column/series to week of year
flights_df['week_of_year'] = flights_df['fl_date'].dt.isocalendar().week

# %% [markdown]
# ### 7. Divide the flight into short, medium, and long haul flights based on air-time

# %%
length=[]

for i in flights_df['air_time']:
    if i < (180): # less than 3 hours
        length.append('short')
    elif (i >= (180)) and (i <= (360)): #between 3 and 6 hours
        length.append('medium')
    else: length.append('long') # more than 6 hours

flights_df['haul_length'] = length

# %% [markdown]
# ### Check

# %%
flights_df.shape
# Out:
# (15927485, 48)

# %%
flights_df.columns
# Out:
# Index(['mkt_carrier', 'mkt_carrier_fl_num', 'fl_date', 'branded_code_share',
#        'op_unique_carrier', 'op_carrier_fl_num', 'origin_airport_id',
#        'origin_city_name', 'dest_airport_id', 'dest_city_name', 'crs_dep_time',
#        'dep_time', 'dep_delay', 'taxi_out', 'taxi_in', 'crs_arr_time',
#        'arr_time', 'arr_delay', 'cancelled', 'cancellation_code', 'diverted',
#        'crs_elapsed_time', 'actual_elapsed_time', 'air_time', 'distance',
#        'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay',
#        'late_aircraft_delay', 'first_dep_time', 'total_add_gtime',
#        'longest_add_gtime', 'origin_city', 'origin_region', 'dest_city',
#        'dest_region', 'day', 'month', 'year', 'crs_arr_hrs', 'crs_dep_hrs',
#        'dep_hrs_ctg', 'arr_hrs_ctg', 'day_of_week', 'day_of_year',
#        'week_of_year', 'haul_length'],
#       dtype='object')

# %%
# Save pd as csv
flights_df.to_csv('flights_before_silvias_part.csv', index=False)

# %% [markdown]
# ## Silvia's part

# %%
from midterm_functions import *

# %%
 # CONVERT crs_dep_time TO DATETIME OBJECT
column = 'crs_dep_time'
flights_df = time_columns(flights_df,column,format='%H%M',dropna=True)

# %%
# To flights table, add columns with the  features for date and forecasting date
flights_df = date_forecast_columns(flights_df,date_column='fl_date',format='%Y-%m-%d')

# %%
# Calculate mean dep_delay and arr_delay for a given carrier 
groupby_columns_1 = ['mkt_carrier', 'origin_airport_id']
columns = ['dep_delay', 'arr_delay'] # columns on which to get aggregate data
flights_df = flights_df.groupby(
    groupby_columns_1,group_keys=False).apply( # for a given month
        lambda x: aggregate(x,columns,'carrier_origin_month').groupby(
    groupby_columns_1,group_keys=False).apply( # for a given WEEK OF THE YEAR
        lambda x: aggregate(x,columns,'carrier_origin_week')).groupby(
    groupby_columns_1,group_keys=False).apply( # for a given DAY OF YEAR
        lambda x: aggregate(x,columns,'carrier_origin_date')))

# %%
# FORECASTING DATA COLUMNS: ['dep_delay', 'arr_delay']
# columns for self-join using forecasting columns
columns_list = [
    'mean_dep_delay_carrier_origin_date',
    'mean_arr_delay_carrier_origin_date'
]

# %%
# Mean delay for the 7 days ago
groupby_tm1_week_date = groupby_columns_1 + ['fl_date_t-1_week_date'] 
# Mean delay for the 1 week before
groupby_tm1_week_week_number = groupby_columns_1 + ['fl_date_t-1_week_week_number']
# Mean delay for the same week 1 year ago
groupby_tm1_year_week = groupby_columns_1 + ['year','fl_date_week_number'] # SH 2022-10-27 19:11 updated
# Mean delay for the same MONTH 1 year ago; 
groupby_tm1_year_month = groupby_columns_1 + ['month'] # SH 2022-10-27 19:11 updated

# %%
flights_df.filter(regex='date').dtypes
# Out:
# fl_date                               datetime64[ns]
# fl_date_dt                            datetime64[ns]
# fl_date_year                           period[A-DEC]
# fl_date_year_month                         period[M]
# fl_date_Monday_of_week                datetime64[ns]
# fl_date_week_number                           UInt32
# fl_date_t-1_week_week_number                  UInt32
# fl_date_t-1_week_date                 datetime64[ns]
# fl_date_t-1_year_year                          int64
# fl_date_t-1_year_month                         int64
# fl_date_t-1_year_day                  datetime64[ns]
# mean_dep_delay_carrier_origin_date           float64
# mean_arr_delay_carrier_origin_date           float64
# dtype: object

# %%
 # ADD FORECASTING COLUMNS WITH SELF-JOIN
flights_df = flights_df.merge( 
                flights_df.filter(items=columns_list + groupby_tm1_week_date).groupby(groupby_tm1_week_date).mean(), # Mean delay for the 7 days ago
                how='left',
                # indicator='merge_tm1_week_date',
                left_on=groupby_columns_1+['fl_date_dt'],
                right_index=True,
                suffixes=[None,'_t-1_week'],
                copy=False
        ).merge( 
                flights_df.filter(items=columns_list + groupby_tm1_week_week_number).groupby(groupby_tm1_week_week_number).mean(), # Mean delay for the 1 week before # YES
                how='left',
                # indicator='merge_tm1_week_week_number',
                left_on=groupby_columns_1+['fl_date_week_number'],
                right_index=True,
                suffixes=[None,'_t-1_week_week_number'],
                copy=False
        ).merge(
                flights_df.filter(items=columns_list+ groupby_tm1_year_week).groupby(groupby_tm1_year_week).mean(), # Mean delay for the same week 1 year ago
                how='left',
                # indicator='merge_tm1_year_week',
                right_index=True, 
                left_on=groupby_columns_1+['fl_date_t-1_year_year','fl_date_week_number'],
                suffixes=[None,'t-1_year_week'],
                copy=False
        ).merge( 
                flights_df.filter(items=columns_list+groupby_tm1_year_month).groupby(groupby_tm1_year_month).mean(),# Mean delay for the same MONTH 1 year ago; 
                how='left',
                # indicator='merge_tm1_year_month',
                left_on=groupby_columns_1+['fl_date_t-1_year_month'],
                right_index=True,
                suffixes=[None,'_t-1_year_month'],
                copy=False

)

# %%
flights_df.columns
# Out:
# Index(['mkt_carrier', 'mkt_carrier_fl_num', 'fl_date', 'branded_code_share',
#        'op_unique_carrier', 'op_carrier_fl_num', 'origin_airport_id',
#        'origin_city_name', 'dest_airport_id', 'dest_city_name', 'crs_dep_time',
#        'dep_time', 'dep_delay', 'taxi_out', 'taxi_in', 'crs_arr_time',
#        'arr_time', 'arr_delay', 'cancelled', 'cancellation_code', 'diverted',
#        'crs_elapsed_time', 'actual_elapsed_time', 'air_time', 'distance',
#        'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay',
#        'late_aircraft_delay', 'first_dep_time', 'total_add_gtime',
#        'longest_add_gtime', 'origin_city', 'origin_region', 'dest_city',
#        'dest_region', 'day', 'month', 'year', 'crs_arr_hrs', 'crs_dep_hrs',
#        'dep_hrs_ctg', 'arr_hrs_ctg', 'day_of_week', 'day_of_year',
#        'week_of_year', 'haul_length', 'crs_dep_time_dt', 'crs_dep_time_hour',
#        'fl_date_dt', 'fl_date_year', 'fl_date_year_month',
#        'fl_date_Monday_of_week', 'fl_date_week_number',
#        'fl_date_t-1_week_week_number', 'fl_date_t-1_week_date',
#        'fl_date_t-1_year_year', 'fl_date_t-1_year_month',
#        'fl_date_t-1_year_day', 'mean_dep_delay_carrier_origin_month',
#        'mean_arr_delay_carrier_origin_month',
#        'mean_dep_delay_carrier_origin_week',
#        'mean_arr_delay_carrier_origin_week',
#        'mean_dep_delay_carrier_origin_date',
#        'mean_arr_delay_carrier_origin_date',
#        'mean_dep_delay_carrier_origin_date_t-1_week',
#        'mean_arr_delay_carrier_origin_date_t-1_week',
#        'mean_dep_delay_carrier_origin_date_t-1_week_week_number',
#        'mean_arr_delay_carrier_origin_date_t-1_week_week_number',
#        'mean_dep_delay_carrier_origin_datet-1_year_week',
#        'mean_arr_delay_carrier_origin_datet-1_year_week',
#        'mean_dep_delay_carrier_origin_date_t-1_year_month',
#        'mean_arr_delay_carrier_origin_date_t-1_year_month'],
#       dtype='object')

# %%
flights_df.shape
# Out:
# (15927485, 74)

# %%
# Drop columns
columns_dropped = ['origin_city_name', 'dest_city_name', 'taxi_out', 'taxi_in', 'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay',
       'late_aircraft_delay']

# %%
flights_df = flights_df.drop(columns = columns_dropped)

# %%
flights_df.shape
# Out:
# (15927485, 65)

# %% [markdown]
# ### SAVE

# %%
# Save the file to CSV
from datetime import datetime
datetime_now = datetime.now().strftime('%Y-%m-%d_%H%M')
filename = f'flights_{datetime_now}.csv'
print(filename)
# Out:
# flights_2022-10-27_1948.csv

# %%
# Save pd as csv
flights_df.to_csv('flights_2022-10-27_1948.csv', index=False)

# %% [markdown]
# Read

# %%
# Read from extracted data
flights_df = pd.read_csv('flights_2022-10-27_1948.csv')
# Out:
# /var/folders/1m/wlv_4s950j15c3grd3ny62mr0000gn/T/ipykernel_36061/3197554248.py:2: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   flights_df = pd.read_csv('flights_2022-10-27_1948.csv')

# %%
# flights_df.set_index(flights_df.columns[0], inplace=True)

# %%
flights_df.columns
# Out:
# Index(['mkt_carrier', 'mkt_carrier_fl_num', 'fl_date', 'branded_code_share',
#        'op_unique_carrier', 'op_carrier_fl_num', 'origin_airport_id',
#        'dest_airport_id', 'crs_dep_time', 'dep_time', 'dep_delay',
#        'crs_arr_time', 'arr_time', 'arr_delay', 'cancelled',
#        'cancellation_code', 'diverted', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'distance', 'first_dep_time',
#        'total_add_gtime', 'longest_add_gtime', 'origin_city', 'origin_region',
#        'dest_city', 'dest_region', 'day', 'month', 'year', 'crs_arr_hrs',
#        'crs_dep_hrs', 'dep_hrs_ctg', 'arr_hrs_ctg', 'day_of_week',
#        'day_of_year', 'week_of_year', 'haul_length', 'crs_dep_time_dt',
#        'crs_dep_time_hour', 'fl_date_dt', 'fl_date_year', 'fl_date_year_month',
#        'fl_date_Monday_of_week', 'fl_date_week_number',
#        'fl_date_t-1_week_week_number', 'fl_date_t-1_week_date',
#        'fl_date_t-1_year_year', 'fl_date_t-1_year_month',
#        'fl_date_t-1_year_day', 'mean_dep_delay_carrier_origin_month',
#        'mean_arr_delay_carrier_origin_month',
#        'mean_dep_delay_carrier_origin_week',
#        'mean_arr_delay_carrier_origin_week',
#        'mean_dep_delay_carrier_origin_date',
#        'mean_arr_delay_carrier_origin_date',
#        'mean_dep_delay_carrier_origin_date_t-1_week',
#        'mean_arr_delay_carrier_origin_date_t-1_week',
#        'mean_dep_delay_carrier_origin_date_t-1_week_week_number',
#        'mean_arr_delay_carrier_origin_date_t-1_week_week_number',
#        'mean_dep_delay_carrier_origin_datet-1_year_week',
#        'mean_arr_delay_carrier_origin_datet-1_year_week',
#        'mean_dep_delay_carrier_origin_date_t-1_year_month',
#        'mean_arr_delay_carrier_origin_date_t-1_year_month'],
#       dtype='object')

# %% [markdown]
# ### Passangers table

# %%
# PASSENGERS TABLE
# Load the CSV file with the variable name `passengers` for convenience.
passengers = pd.read_csv('../data/passengers_2022-10-27_1727.csv')

# %%
# Calculate average per departure
col_for_averaging = [
    'payload',
    'seats',
    'passengers',
    'freight',
    'mail',
]

# %%
# Calculate average per departure
for column in col_for_averaging:
    passengers[str('mean_'+column+'_per_departure')] = passengers[column] / passengers['departures_performed']

# %%
# calculate mean empty seats
passengers['mean_empty_seats_per_departure'] = passengers['mean_seats_per_departure'] - passengers['mean_passengers_per_departure']

# %%
# Drop columns whose data were put into the new columns as 'mean_.*'
passengers.drop(columns=col_for_averaging, inplace=True)

# %%
passengers.shape
# Out:
# (515663, 16)

# %% [markdown]
# ### Merge Flights df with Passengers df

# %%
# Prepare for the merge!
left_join_columns = ['mkt_carrier','origin_airport_id', 'dest_airport_id', 
    'fl_date_t-1_year_year', 'month']
right_join_columns = ['carrier','origin_airport_id', 'dest_airport_id', 
    'year', 'month']

# %%
# Join flights and passengers table
flights = flights_df.merge(
    passengers,how='left',left_on=left_join_columns, 
    right_on=right_join_columns, indicator=True
)
flights
# Out:
#          mkt_carrier  mkt_carrier_fl_num     fl_date branded_code_share  \
# 0                 AS                 121  2019-08-22                 AS
# 1                 AS                 121  2019-08-22                 AS
# 2                 AS                 121  2019-08-22                 AS
# 3                 AS                 121  2019-08-22                 AS
# 4                 AS                 121  2019-08-22                 AS
# ...              ...                 ...         ...                ...
# 26981363          AS                 120  2019-08-22                 AS
# 26981364          AS                 120  2019-08-22                 AS
# 26981365          AS                 120  2019-08-22                 AS
# 26981366          AS                 120  2019-08-22                 AS
# 26981367          AS                 120  2019-08-22                 AS
#
#          op_unique_carrier  op_carrier_fl_num  origin_airport_id  \
# 0                       AS                121              14747
# 1                       AS                121              14747
# 2                       AS                121              14747
# 3                       AS                121              14747
# 4                       AS                121              14747
# ...                    ...                ...                ...
# 26981363                AS                120              10299
# 26981364                AS                120              10299
# 26981365                AS                120              10299
# 26981366                AS                120              10299
# 26981367                AS                120              10299
#
#           dest_airport_id  crs_dep_time  dep_time  ...  unique_carrier  \
# 0                   10299            40      37.0  ...              AS
# 1                   10299            40      37.0  ...              AS
# 2                   10299            40      37.0  ...              AS
# 3                   10299            40      37.0  ...              AS
# 4                   10299            40      37.0  ...              AS
# ...                   ...           ...       ...  ...             ...
# 26981363            14747          1630    1622.0  ...              AS
# 26981364            14747          1630    1622.0  ...              AS
# 26981365            14747          1630    1622.0  ...              AS
# 26981366            14747          1630    1622.0  ...              AS
# 26981367            14747          1630    1622.0  ...              AS
#
#           airline_id  year_y  mean_payload_per_departure  \
# 0            19930.0  2018.0                39916.129032
# 1            19930.0  2018.0                34050.000000
# 2            19930.0  2018.0                39912.500000
# 3            19930.0  2018.0                42708.247423
# 4            19930.0  2018.0                46199.092971
# ...              ...     ...                         ...
# 26981363     19930.0  2018.0                39700.000000
# 26981364     19930.0  2018.0                33900.000000
# 26981365     19930.0  2018.0                39963.461538
# 26981366     19930.0  2018.0                42704.123711
# 26981367     19930.0  2018.0                46193.392070
#
#           mean_seats_per_departure mean_passengers_per_departure  \
# 0                              0.0                      0.000000
# 1                            124.0                    103.750000
# 2                            159.0                    127.479167
# 3                            178.0                    138.000000
# 4                            178.0                    142.623583
# ...                            ...                           ...
# 26981363                       0.0                      0.000000
# 26981364                     124.0                    108.500000
# 26981365                     159.0                    138.538462
# 26981366                     178.0                    160.896907
# 26981367                     178.0                    160.971366
#
#           mean_freight_per_departure  mean_mail_per_departure  \
# 0                       20607.419355              2626.096774
# 1                         159.600000                 4.150000
# 2                        1134.729167                22.437500
# 3                        1069.041237                59.773196
# 4                         995.428571                83.068027
# ...                              ...                      ...
# 26981363                24340.142857              1393.571429
# 26981364                 1221.333333                 0.000000
# 26981365                  838.865385                47.980769
# 26981366                  489.680412                18.371134
# 26981367                  902.982379                35.986784
#
#           mean_empty_seats_per_departure  _merge
# 0                               0.000000    both
# 1                              20.250000    both
# 2                              31.520833    both
# 3                              40.000000    both
# 4                              35.376417    both
# ...                                  ...     ...
# 26981363                        0.000000    both
# 26981364                       15.500000    both
# 26981365                       20.461538    both
# 26981366                       17.103093    both
# 26981367                       17.028634    both
#
# [26981368 rows x 79 columns]

# %%
flights.drop_duplicates(subset=['mkt_carrier','fl_date','mkt_carrier_fl_num'], inplace=True)

# %%
flights.shape
# Out:
# (12347377, 79)

# %% [markdown]
# ### Save

# %%
# Save pd as csv
flights_df.to_csv('flights_passengers_2022-10-27_2035.csv', index=False)

# %% [markdown]
# # Cleaning

# %%
flights.head()
# Out:
#    mkt_carrier  mkt_carrier_fl_num     fl_date branded_code_share  \
# 0           AS                 121  2019-08-22                 AS
# 5           AS                 122  2019-08-22                 AS
# 10          AS                 123  2019-08-22                 AS
# 13          AS                 124  2019-08-22                 AS
# 17          AS                 125  2019-08-22                 AS
#
#    op_unique_carrier  op_carrier_fl_num  origin_airport_id  dest_airport_id  \
# 0                 AS                121              14747            10299
# 5                 AS                122              10299            14747
# 10                AS                123              14747            11630
# 13                AS                124              11630            14747
# 17                AS                125              14057            10299
#
#     crs_dep_time  dep_time  ...  unique_carrier  airline_id  year_y  \
# 0             40      37.0  ...              AS     19930.0  2018.0
# 5           1940    1929.0  ...              AS     19930.0  2018.0
# 10          1350    1352.0  ...              AS     19930.0  2018.0
# 13          1755    1745.0  ...              AS     19930.0  2018.0
# 17           700     654.0  ...              AS     19930.0  2018.0
#
#     mean_payload_per_departure  mean_seats_per_departure  \
# 0                 39916.129032                       0.0
# 5                 39700.000000                       0.0
# 10                39800.000000                     159.0
# 13                33700.000000                     124.0
# 17                42550.000000                     178.0
#
#    mean_passengers_per_departure  mean_freight_per_departure  \
# 0                           0.00                20607.419355
# 5                           0.00                24340.142857
# 10                        142.00                  445.500000
# 13                        116.00                  576.000000
# 17                        141.25                 1169.750000
#
#     mean_mail_per_departure  mean_empty_seats_per_departure  _merge
# 0               2626.096774                            0.00    both
# 5               1393.571429                            0.00    both
# 10                 0.000000                           17.00    both
# 13                 0.000000                            8.00    both
# 17               194.500000                           36.75    both
#
# [5 rows x 79 columns]

# %% [markdown]
# #### EDA

# %%
flights_df = flights[(flights['cancelled'] != 1) & (flights['diverted']!= 1)]

# %%
flights_df.shape
# Out:
# (12106445, 79)

# %%
explore(flights_df,print_n_unique=False).head(30)
# Out:
# Unique IDs: 11. # of rows: 12106445. Match: False
#                                                        Total       Percent
# cancellation_code                                   12106445  1.000000e+00
# total_add_gtime                                     12024921  9.932661e-01
# longest_add_gtime                                   12024918  9.932658e-01
# first_dep_time                                      12024916  9.932657e-01
# mean_empty_seats_per_departure                       7759021  6.409000e-01
# mean_mail_per_departure                              7759021  6.409000e-01
# mean_freight_per_departure                           7759021  6.409000e-01
# mean_passengers_per_departure                        7759021  6.409000e-01
# mean_seats_per_departure                             7759021  6.409000e-01
# mean_payload_per_departure                           7759021  6.409000e-01
# unique_carrier                                       7754850  6.405555e-01
# departures_performed                                 7754850  6.405555e-01
# distance_y                                           7754850  6.405555e-01
# carrier                                              7754850  6.405555e-01
# Unnamed: 0                                           7754850  6.405555e-01
# airline_id                                           7754850  6.405555e-01
# year_y                                               7754850  6.405555e-01
# mean_arr_delay_carrier_origin_datet-1_year_week      6005636  4.960693e-01
# mean_dep_delay_carrier_origin_datet-1_year_week      6005636  4.960693e-01
# mean_arr_delay_carrier_origin_date_t-1_week           125432  1.036076e-02
# mean_dep_delay_carrier_origin_date_t-1_week           125432  1.036076e-02
# air_time                                                6076  5.018814e-04
# dep_delay                                               4142  3.421318e-04
# arr_delay                                               2229  1.841168e-04
# mean_dep_delay_carrier_origin_date_t-1_week_wee...      1825  1.507462e-04
# mean_arr_delay_carrier_origin_date_t-1_week_wee...      1825  1.507462e-04
# actual_elapsed_time                                       12  9.912076e-07
# arr_time                                                  10  8.260063e-07
# dep_time                                                   8  6.608051e-07
# crs_elapsed_time                                           1  8.260063e-08

# %%
# FLIGHTS TABLE TRAINING DATA: Fill mean flight historical/forecasting delay data. 
dict = {
    'mean_dep_delay_carrier_origin_date_t-1_week': 'mean_dep_delay_carrier_origin_week', 
    'mean_arr_delay_carrier_origin_date_t-1_week': 'mean_arr_delay_carrier_origin_week',
    'mean_dep_delay_carrier_origin_date_t-1_week_week_number': 'mean_dep_delay_carrier_origin_week',
    'mean_arr_delay_carrier_origin_date_t-1_week_week_number': 'mean_arr_delay_carrier_origin_week',
    'mean_dep_delay_carrier_origin_datet-1_year_week': 'mean_dep_delay_carrier_origin_week', # DON'T USE THIS FOR NOW
    'mean_arr_delay_carrier_origin_datet-1_year_week': 'mean_arr_delay_carrier_origin_week', # DON'T USE THIS FOR NOW
    'mean_dep_delay_carrier_origin_date_t-1_year_month': 'mean_dep_delay_carrier_origin_month', # DON'T USE THIS FOR NOW
    'mean_arr_delay_carrier_origin_date_t-1_year_month': 'mean_arr_delay_carrier_origin_month' # DON'T USE THIS FOR NOW
}
fill_missing(flights_df,dict,fill_w_mean=False) # Call the function
explore(flights_df.filter(regex='mean')) # Recheck missing values
# Out:
# /Users/ava_mac/Documents/Coding/LHL/W6/Predicting_Flight_Delays_Midterm/src/midterm_functions.py:332: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_to_fill].fillna(df[column_filler], inplace=True)
# Unique IDs: 1320. # of rows: 12106445. Match: False
#                                                       Total  Percent
# mean_empty_seats_per_departure                      7759021   0.6409
# mean_mail_per_departure                             7759021   0.6409
# mean_freight_per_departure                          7759021   0.6409
# mean_passengers_per_departure                       7759021   0.6409
# mean_seats_per_departure                            7759021   0.6409
# mean_payload_per_departure                          7759021   0.6409
# mean_arr_delay_carrier_origin_month                       0   0.0000
# mean_arr_delay_carrier_origin_date_t-1_year_month         0   0.0000
# mean_dep_delay_carrier_origin_date_t-1_year_month         0   0.0000
# mean_arr_delay_carrier_origin_datet-1_year_week           0   0.0000
# mean_dep_delay_carrier_origin_month                       0   0.0000
# mean_arr_delay_carrier_origin_date_t-1_week_wee...        0   0.0000
# mean_dep_delay_carrier_origin_date_t-1_week_wee...        0   0.0000
# mean_arr_delay_carrier_origin_date_t-1_week               0   0.0000
# mean_dep_delay_carrier_origin_date_t-1_week               0   0.0000
# mean_arr_delay_carrier_origin_date                        0   0.0000
# mean_dep_delay_carrier_origin_date                        0   0.0000
# mean_arr_delay_carrier_origin_week                        0   0.0000
# mean_dep_delay_carrier_origin_week                        0   0.0000
# mean_dep_delay_carrier_origin_datet-1_year_week           0   0.0000

# %%
df_with_passangers = flights_df.copy()

# %%
flights = df_with_passangers.copy()

# %%
# REMOVE FEATURES WITH NULL VALUES ABOVE THRESHOLD

def drop_features(df,threshold=100, show_update=True):
    """
    Drop columns in a dataframe with null values above the specified threshold.
    Parameters:
    - df: Dataframe.
    - threshold (float): Float between 0 and 100. 
        Threshold of % null values over which columns will be dropped.
    - show_update: If true, show missing values for the updated dataframe
        (calls the custom function explore)
    """ 
    
    # count amount of missing values in each column
    total = df.isnull().sum().sort_values(ascending=False) 
    # % of rows with missing data from each column
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False) 

    # create a table that lists total and % of missing values starting with the highest
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent']) 

    filter = missing_data['Percent'] > threshold
    to_drop = missing_data[filter].index.tolist()
    df.drop(to_drop, axis=1, inplace=True)
    print(f'Threshold of percentage values for dropping columns: {threshold}')
    print(f'Columns dropped: {to_drop}')
    # if show_update == True:
        # return explore(df,id=0,print_n_unique=False, printValues=False)
    return df

# %%
# REMOVE FEATURES WITH NULL VALUES ABOVE THRESHOLD
threshold = 0.6
flights = drop_features(flights,threshold=threshold,show_update=True)
# Out:
# Threshold of percentage values for dropping columns: 0.6
# Columns dropped: ['mean_empty_seats_per_departure', 'mean_mail_per_departure', 'mean_freight_per_departure', 'mean_passengers_per_departure', 'mean_seats_per_departure', 'mean_payload_per_departure', 'departures_performed', 'airline_id', 'Unnamed: 0', 'distance_y', 'unique_carrier', 'carrier', 'year_y']

# %%
flights.shape
# Out:
# (12106445, 62)

# %%
explore(flights).head(30)
# Out:
# Unique IDs: 11. # of rows: 12106445. Match: False
#                                                     Total       Percent
# air_time                                             6076  5.018814e-04
# dep_delay                                            4142  3.421318e-04
# arr_delay                                            2229  1.841168e-04
# actual_elapsed_time                                    12  9.912076e-07
# arr_time                                               10  8.260063e-07
# dep_time                                                8  6.608051e-07
# crs_elapsed_time                                        1  8.260063e-08
# fl_date_year_month                                      0  0.000000e+00
# fl_date_Monday_of_week                                  0  0.000000e+00
# fl_date_week_number                                     0  0.000000e+00
# fl_date_t-1_week_week_number                            0  0.000000e+00
# fl_date_t-1_week_date                                   0  0.000000e+00
# mean_dep_delay_carrier_origin_week                      0  0.000000e+00
# fl_date_t-1_year_year                                   0  0.000000e+00
# fl_date_year                                            0  0.000000e+00
# fl_date_t-1_year_month                                  0  0.000000e+00
# fl_date_t-1_year_day                                    0  0.000000e+00
# mean_dep_delay_carrier_origin_month                     0  0.000000e+00
# fl_date_dt                                              0  0.000000e+00
# mean_arr_delay_carrier_origin_month                     0  0.000000e+00
# mkt_carrier                                             0  0.000000e+00
# mean_arr_delay_carrier_origin_week                      0  0.000000e+00
# crs_dep_time_dt                                         0  0.000000e+00
# mean_dep_delay_carrier_origin_date                      0  0.000000e+00
# mean_arr_delay_carrier_origin_date                      0  0.000000e+00
# mean_dep_delay_carrier_origin_date_t-1_week             0  0.000000e+00
# mean_arr_delay_carrier_origin_date_t-1_week             0  0.000000e+00
# mean_dep_delay_carrier_origin_date_t-1_week_wee...      0  0.000000e+00
# mean_arr_delay_carrier_origin_date_t-1_week_wee...      0  0.000000e+00
# mean_dep_delay_carrier_origin_datet-1_year_week         0  0.000000e+00

# %% [markdown]
# Save just in case, not be used because of a big size of rows and missing passangers columns

# %%
# Save pd as csv
flights.to_csv('flights_data_2022-10-27_2155.csv', index=False)

# %% [markdown]
# Use this data for scaling, modelling

# %%
df = df_with_passangers.dropna(how='any')

# %%
df_with_passangers.columns
# Out:
# Index(['mkt_carrier', 'mkt_carrier_fl_num', 'fl_date', 'branded_code_share',
#        'op_unique_carrier', 'op_carrier_fl_num', 'origin_airport_id',
#        'dest_airport_id', 'crs_dep_time', 'dep_time', 'dep_delay',
#        'crs_arr_time', 'arr_time', 'arr_delay', 'cancelled',
#        'cancellation_code', 'diverted', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'distance_x', 'first_dep_time',
#        'total_add_gtime', 'longest_add_gtime', 'origin_city', 'origin_region',
#        'dest_city', 'dest_region', 'day', 'month', 'year_x', 'crs_arr_hrs',
#        'crs_dep_hrs', 'dep_hrs_ctg', 'arr_hrs_ctg', 'day_of_week',
#        'day_of_year', 'week_of_year', 'haul_length', 'crs_dep_time_dt',
#        'crs_dep_time_hour', 'fl_date_dt', 'fl_date_year', 'fl_date_year_month',
#        'fl_date_Monday_of_week', 'fl_date_week_number',
#        'fl_date_t-1_week_week_number', 'fl_date_t-1_week_date',
#        'fl_date_t-1_year_year', 'fl_date_t-1_year_month',
#        'fl_date_t-1_year_day', 'mean_dep_delay_carrier_origin_month',
#        'mean_arr_delay_carrier_origin_month',
#        'mean_dep_delay_carrier_origin_week',
#        'mean_arr_delay_carrier_origin_week',
#        'mean_dep_delay_carrier_origin_date',
#        'mean_arr_delay_carrier_origin_date',
#        'mean_dep_delay_carrier_origin_date_t-1_week',
#        'mean_arr_delay_carrier_origin_date_t-1_week',
#        'mean_dep_delay_carrier_origin_date_t-1_week_week_number',
#        'mean_arr_delay_carrier_origin_date_t-1_week_week_number',
#        'mean_dep_delay_carrier_origin_datet-1_year_week',
#        'mean_arr_delay_carrier_origin_datet-1_year_week',
#        'mean_dep_delay_carrier_origin_date_t-1_year_month',
#        'mean_arr_delay_carrier_origin_date_t-1_year_month', 'Unnamed: 0',
#        'departures_performed', 'distance_y', 'carrier', 'unique_carrier',
#        'airline_id', 'year_y', 'mean_payload_per_departure',
#        'mean_seats_per_departure', 'mean_passengers_per_departure',
#        'mean_freight_per_departure', 'mean_mail_per_departure',
#        'mean_empty_seats_per_departure', '_merge'],
#       dtype='object')

# %%
# Save pd as csv
df_with_passangers.to_csv('df_with_passangers_2022-10-27_1005.csv', index=False)

# %%
# Read from extracted data
df_with_passangers = pd.read_csv('df_with_passangers_2022-10-27_1005.csv')
# Out:
# /var/folders/1m/wlv_4s950j15c3grd3ny62mr0000gn/T/ipykernel_39496/1390462780.py:2: DtypeWarning: Columns (68,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_with_passangers = pd.read_csv('df_with_passangers_2022-10-27_1005.csv')

# %%
explore(df_with_passangers).head(30)
# Out:
# Unique IDs: 11. # of rows: 12106445. Match: False
#                                         Total       Percent
# cancellation_code                    12106445  1.000000e+00
# total_add_gtime                      12024921  9.932661e-01
# longest_add_gtime                    12024918  9.932658e-01
# first_dep_time                       12024916  9.932657e-01
# mean_empty_seats_per_departure        7759021  6.409000e-01
# mean_mail_per_departure               7759021  6.409000e-01
# mean_freight_per_departure            7759021  6.409000e-01
# mean_passengers_per_departure         7759021  6.409000e-01
# mean_seats_per_departure              7759021  6.409000e-01
# mean_payload_per_departure            7759021  6.409000e-01
# unique_carrier                        7754850  6.405555e-01
# distance_y                            7754850  6.405555e-01
# Unnamed: 0                            7754850  6.405555e-01
# carrier                               7754850  6.405555e-01
# airline_id                            7754850  6.405555e-01
# year_y                                7754850  6.405555e-01
# departures_performed                  7754850  6.405555e-01
# air_time                                 6076  5.018814e-04
# dep_delay                                4142  3.421318e-04
# arr_delay                                2229  1.841168e-04
# actual_elapsed_time                        12  9.912076e-07
# arr_time                                   10  8.260063e-07
# dep_time                                    8  6.608051e-07
# crs_elapsed_time                            1  8.260063e-08
# fl_date_t-1_week_date                       0  0.000000e+00
# mean_arr_delay_carrier_origin_date          0  0.000000e+00
# fl_date_t-1_year_year                       0  0.000000e+00
# fl_date_t-1_year_month                      0  0.000000e+00
# fl_date_t-1_year_day                        0  0.000000e+00
# mean_dep_delay_carrier_origin_month         0  0.000000e+00

# %%
df_with_passangers.columns
# Out:
# Index(['mkt_carrier', 'mkt_carrier_fl_num', 'fl_date', 'branded_code_share',
#        'op_unique_carrier', 'op_carrier_fl_num', 'origin_airport_id',
#        'dest_airport_id', 'crs_dep_time', 'dep_time', 'dep_delay',
#        'crs_arr_time', 'arr_time', 'arr_delay', 'cancelled',
#        'cancellation_code', 'diverted', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'distance_x', 'first_dep_time',
#        'total_add_gtime', 'longest_add_gtime', 'origin_city', 'origin_region',
#        'dest_city', 'dest_region', 'day', 'month', 'year_x', 'crs_arr_hrs',
#        'crs_dep_hrs', 'dep_hrs_ctg', 'arr_hrs_ctg', 'day_of_week',
#        'day_of_year', 'week_of_year', 'haul_length', 'crs_dep_time_dt',
#        'crs_dep_time_hour', 'fl_date_dt', 'fl_date_year', 'fl_date_year_month',
#        'fl_date_Monday_of_week', 'fl_date_week_number',
#        'fl_date_t-1_week_week_number', 'fl_date_t-1_week_date',
#        'fl_date_t-1_year_year', 'fl_date_t-1_year_month',
#        'fl_date_t-1_year_day', 'mean_dep_delay_carrier_origin_month',
#        'mean_arr_delay_carrier_origin_month',
#        'mean_dep_delay_carrier_origin_week',
#        'mean_arr_delay_carrier_origin_week',
#        'mean_dep_delay_carrier_origin_date',
#        'mean_arr_delay_carrier_origin_date',
#        'mean_dep_delay_carrier_origin_date_t-1_week',
#        'mean_arr_delay_carrier_origin_date_t-1_week',
#        'mean_dep_delay_carrier_origin_date_t-1_week_week_number',
#        'mean_arr_delay_carrier_origin_date_t-1_week_week_number',
#        'mean_dep_delay_carrier_origin_datet-1_year_week',
#        'mean_arr_delay_carrier_origin_datet-1_year_week',
#        'mean_dep_delay_carrier_origin_date_t-1_year_month',
#        'mean_arr_delay_carrier_origin_date_t-1_year_month', 'Unnamed: 0',
#        'departures_performed', 'distance_y', 'carrier', 'unique_carrier',
#        'airline_id', 'year_y', 'mean_payload_per_departure',
#        'mean_seats_per_departure', 'mean_passengers_per_departure',
#        'mean_freight_per_departure', 'mean_mail_per_departure',
#        'mean_empty_seats_per_departure', '_merge'],
#       dtype='object')

# %%
df = df_with_passangers.dropna(subset=['departures_performed', 'distance_x', 'distance_y', 'unique_carrier', 'airline_id',
       'origin_airport_id', 'dest_airport_id', 'year_x','year_y', 'month',
       'mean_payload_per_departure', 'mean_seats_per_departure',
       'mean_passengers_per_departure', 'mean_freight_per_departure',
       'mean_mail_per_departure', 'mean_empty_seats_per_departure'])

# %%
df_with_passangers.shape
# Out:
# (12106445, 79)

# %%
df.shape
# Out:
# (4347424, 79)

# %%
df.columns
# Out:
# Index(['mkt_carrier', 'mkt_carrier_fl_num', 'fl_date', 'branded_code_share',
#        'op_unique_carrier', 'op_carrier_fl_num', 'origin_airport_id',
#        'dest_airport_id', 'crs_dep_time', 'dep_time', 'dep_delay',
#        'crs_arr_time', 'arr_time', 'arr_delay', 'cancelled',
#        'cancellation_code', 'diverted', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'distance_x', 'first_dep_time',
#        'total_add_gtime', 'longest_add_gtime', 'origin_city', 'origin_region',
#        'dest_city', 'dest_region', 'day', 'month', 'year_x', 'crs_arr_hrs',
#        'crs_dep_hrs', 'dep_hrs_ctg', 'arr_hrs_ctg', 'day_of_week',
#        'day_of_year', 'week_of_year', 'haul_length', 'crs_dep_time_dt',
#        'crs_dep_time_hour', 'fl_date_dt', 'fl_date_year', 'fl_date_year_month',
#        'fl_date_Monday_of_week', 'fl_date_week_number',
#        'fl_date_t-1_week_week_number', 'fl_date_t-1_week_date',
#        'fl_date_t-1_year_year', 'fl_date_t-1_year_month',
#        'fl_date_t-1_year_day', 'mean_dep_delay_carrier_origin_month',
#        'mean_arr_delay_carrier_origin_month',
#        'mean_dep_delay_carrier_origin_week',
#        'mean_arr_delay_carrier_origin_week',
#        'mean_dep_delay_carrier_origin_date',
#        'mean_arr_delay_carrier_origin_date',
#        'mean_dep_delay_carrier_origin_date_t-1_week',
#        'mean_arr_delay_carrier_origin_date_t-1_week',
#        'mean_dep_delay_carrier_origin_date_t-1_week_week_number',
#        'mean_arr_delay_carrier_origin_date_t-1_week_week_number',
#        'mean_dep_delay_carrier_origin_datet-1_year_week',
#        'mean_arr_delay_carrier_origin_datet-1_year_week',
#        'mean_dep_delay_carrier_origin_date_t-1_year_month',
#        'mean_arr_delay_carrier_origin_date_t-1_year_month', 'Unnamed: 0',
#        'departures_performed', 'distance_y', 'carrier', 'unique_carrier',
#        'airline_id', 'year_y', 'mean_payload_per_departure',
#        'mean_seats_per_departure', 'mean_passengers_per_departure',
#        'mean_freight_per_departure', 'mean_mail_per_departure',
#        'mean_empty_seats_per_departure', '_merge'],
#       dtype='object')

# %%
explore(df)
# Out:
# Unique IDs: 10. # of rows: 4347424. Match: False
#                                       Total   Percent
# cancellation_code                   4347424  1.000000
# total_add_gtime                     4317895  0.993208
# longest_add_gtime                   4317894  0.993207
# first_dep_time                      4317893  0.993207
# mean_dep_delay_carrier_origin_week        0  0.000000
# ...                                     ...       ...
# day                                       0  0.000000
# dest_region                               0  0.000000
# dest_city                                 0  0.000000
# origin_region                             0  0.000000
# _merge                                    0  0.000000
#
# [79 rows x 2 columns]

# %%
df = df.drop(columns = ['actual_elapsed_time', 'cancellation_code', 'arr_time', 'dep_time', ])

# %%
df.shape
# Out:
# (4347424, 75)

# %%
explore(df).head(30)
# Out:
# Unique IDs: 10. # of rows: 4347424. Match: False
#                                                       Total   Percent
# total_add_gtime                                     4317895  0.993208
# longest_add_gtime                                   4317894  0.993207
# first_dep_time                                      4317893  0.993207
# mean_dep_delay_carrier_origin_datet-1_year_week           0  0.000000
# mean_dep_delay_carrier_origin_date_t-1_week_wee...        0  0.000000
# mean_arr_delay_carrier_origin_date_t-1_week               0  0.000000
# mean_dep_delay_carrier_origin_date_t-1_week               0  0.000000
# mean_arr_delay_carrier_origin_date                        0  0.000000
# mean_dep_delay_carrier_origin_date                        0  0.000000
# mean_arr_delay_carrier_origin_week                        0  0.000000
# mean_dep_delay_carrier_origin_week                        0  0.000000
# mean_arr_delay_carrier_origin_month                       0  0.000000
# mean_dep_delay_carrier_origin_month                       0  0.000000
# fl_date_t-1_year_day                                      0  0.000000
# fl_date_t-1_year_month                                    0  0.000000
# fl_date_t-1_year_year                                     0  0.000000
# fl_date_t-1_week_date                                     0  0.000000
# fl_date_t-1_week_week_number                              0  0.000000
# fl_date_week_number                                       0  0.000000
# mean_arr_delay_carrier_origin_date_t-1_week_wee...        0  0.000000
# mkt_carrier                                               0  0.000000
# mean_arr_delay_carrier_origin_datet-1_year_week           0  0.000000
# fl_date_year_month                                        0  0.000000
# mean_empty_seats_per_departure                            0  0.000000
# mean_mail_per_departure                                   0  0.000000
# mean_freight_per_departure                                0  0.000000
# mean_passengers_per_departure                             0  0.000000
# mean_seats_per_departure                                  0  0.000000
# mean_payload_per_departure                                0  0.000000
# year_y                                                    0  0.000000

# %%
def fill_with_mean(df,columns,agg='mean',inplace=True):
    """
    Get the average value in the column.

    Parmaters:
    - Data: `Dataframe groupby().apply()` argument.
    - Columns: Column names on which to perform calculations. Use a list for multiple.
    - agg (string, optional): Aggregate function to apply. Default is mean.
    """

    for column in columns:
        mean = df.loc[:,column].agg(agg)
        df.fillna(mean, inplace=True)

    return df

# %%
groupby_columns = ['mkt_carrier']
columns_to_fill = ['total_add_gtime', 'longest_add_gtime', 'first_dep_time']
df = df.groupby(groupby_columns,group_keys=False).apply( 
        lambda x: fill_with_mean(x,columns_to_fill))

# %%
explore(df).head(30)
# Out:
# Unique IDs: 10. # of rows: 4347424. Match: False
#                                                     Total  Percent
# mkt_carrier                                             0      0.0
# mean_arr_delay_carrier_origin_date_t-1_week_wee...      0      0.0
# mean_arr_delay_carrier_origin_date_t-1_week             0      0.0
# mean_dep_delay_carrier_origin_date_t-1_week             0      0.0
# mean_arr_delay_carrier_origin_date                      0      0.0
# mean_dep_delay_carrier_origin_date                      0      0.0
# mean_arr_delay_carrier_origin_week                      0      0.0
# mean_dep_delay_carrier_origin_week                      0      0.0
# mean_arr_delay_carrier_origin_month                     0      0.0
# mean_dep_delay_carrier_origin_month                     0      0.0
# fl_date_t-1_year_day                                    0      0.0
# fl_date_t-1_year_month                                  0      0.0
# fl_date_t-1_year_year                                   0      0.0
# fl_date_t-1_week_date                                   0      0.0
# fl_date_t-1_week_week_number                            0      0.0
# fl_date_week_number                                     0      0.0
# fl_date_Monday_of_week                                  0      0.0
# mean_dep_delay_carrier_origin_date_t-1_week_wee...      0      0.0
# mean_dep_delay_carrier_origin_datet-1_year_week         0      0.0
# fl_date_year                                            0      0.0
# mean_arr_delay_carrier_origin_datet-1_year_week         0      0.0
# mean_empty_seats_per_departure                          0      0.0
# mean_mail_per_departure                                 0      0.0
# mean_freight_per_departure                              0      0.0
# mean_passengers_per_departure                           0      0.0
# mean_seats_per_departure                                0      0.0
# mean_payload_per_departure                              0      0.0
# year_y                                                  0      0.0
# airline_id                                              0      0.0
# unique_carrier                                          0      0.0

# %%
# Save pd as csv
df.to_csv('data_for_modeling_2022-10-28-1208.csv', index=False)

# %%
#show all columns that have a class of object
df.dtypes[df.dtypes == 'object']
# Out:
# mkt_carrier               object
# fl_date                   object
# branded_code_share        object
# op_unique_carrier         object
# origin_city               object
# origin_region             object
# dest_city                 object
# dest_region               object
# dep_hrs_ctg               object
# arr_hrs_ctg               object
# day_of_week               object
# haul_length               object
# crs_dep_time_dt           object
# fl_date_dt                object
# fl_date_year_month        object
# fl_date_Monday_of_week    object
# fl_date_t-1_week_date     object
# fl_date_t-1_year_day      object
# carrier                   object
# unique_carrier            object
# _merge                    object
# dtype: object

# %%
columns_drop = [
'fl_date',
'mkt_carrier', 
'branded_code_share',
'op_unique_carrier',
'origin_city',
'dest_city',
'fl_date_dt',
'fl_date_year_month',        
'fl_date_Monday_of_week',    
'fl_date_t-1_week_date',     
'fl_date_t-1_year_day',
'_merge',
'carrier',                   
'unique_carrier',
'crs_dep_time_dt'            
]

# %%
df_flight = df.drop(columns = columns_drop)

# %%
#show all columns that have a class of object
df_flight.dtypes[df_flight.dtypes == 'object']
# Out:
# origin_region    object
# dest_region      object
# dep_hrs_ctg      object
# arr_hrs_ctg      object
# day_of_week      object
# haul_length      object
# dtype: object

# %%
# Categorical variables convert to a numerical 
df_flight = pd.get_dummies(df_flight)

# %%
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4347424 entries, 0 to 12106444
# Data columns (total 80 columns):
#  #   Column                                                   Dtype
# ---  ------                                                   -----
#  0   mkt_carrier_fl_num                                       int64
#  1   op_carrier_fl_num                                        int64
#  2   origin_airport_id                                        int64
#  3   dest_airport_id                                          int64
#  4   crs_dep_time                                             int64
#  5   dep_delay                                                float64
#  6   crs_arr_time                                             int64
#  7   arr_delay                                                float64
#  8   cancelled                                                float64
#  9   diverted                                                 float64
#  10  crs_elapsed_time                                         float64
#  11  air_time                                                 float64
#  12  distance_x                                               float64
#  13  first_dep_time                                           float64
#  14  total_add_gtime                                          float64
#  15  longest_add_gtime                                        float64
#  16  day                                                      int64
#  17  month                                                    int64
#  18  year_x                                                   int64
#  19  crs_arr_hrs                                              int64
#  20  crs_dep_hrs                                              int64
#  21  day_of_year                                              int64
#  22  week_of_year                                             int64
#  23  crs_dep_time_hour                                        int64
#  24  fl_date_year                                             int64
#  25  fl_date_week_number                                      int64
#  26  fl_date_t-1_week_week_number                             int64
#  27  fl_date_t-1_year_year                                    int64
#  28  fl_date_t-1_year_month                                   int64
#  29  mean_dep_delay_carrier_origin_month                      float64
#  30  mean_arr_delay_carrier_origin_month                      float64
#  31  mean_dep_delay_carrier_origin_week                       float64
#  32  mean_arr_delay_carrier_origin_week                       float64
#  33  mean_dep_delay_carrier_origin_date                       float64
#  34  mean_arr_delay_carrier_origin_date                       float64
#  35  mean_dep_delay_carrier_origin_date_t-1_week              float64
#  36  mean_arr_delay_carrier_origin_date_t-1_week              float64
#  37  mean_dep_delay_carrier_origin_date_t-1_week_week_number  float64
#  38  mean_arr_delay_carrier_origin_date_t-1_week_week_number  float64
#  39  mean_dep_delay_carrier_origin_datet-1_year_week          float64
#  40  mean_arr_delay_carrier_origin_datet-1_year_week          float64
#  41  mean_dep_delay_carrier_origin_date_t-1_year_month        float64
#  42  mean_arr_delay_carrier_origin_date_t-1_year_month        float64
#  43  Unnamed: 0                                               float64
#  44  departures_performed                                     float64
#  45  distance_y                                               float64
#  46  airline_id                                               float64
#  47  year_y                                                   float64
#  48  mean_payload_per_departure                               float64
#  49  mean_seats_per_departure                                 float64
#  50  mean_passengers_per_departure                            float64
#  51  mean_freight_per_departure                               float64
#  52  mean_mail_per_departure                                  float64
#  53  mean_empty_seats_per_departure                           float64
#  54  origin_region_Midwest                                    uint8
#  55  origin_region_Northeast                                  uint8
#  56  origin_region_South                                      uint8
#  57  origin_region_West                                       uint8
#  58  dest_region_Midwest                                      uint8
#  59  dest_region_Northeast                                    uint8
#  60  dest_region_South                                        uint8
#  61  dest_region_West                                         uint8
#  62  dep_hrs_ctg_Afternoon                                    uint8
#  63  dep_hrs_ctg_Evening                                      uint8
#  64  dep_hrs_ctg_Morning                                      uint8
#  65  dep_hrs_ctg_Night                                        uint8
#  66  arr_hrs_ctg_Afternoon                                    uint8
#  67  arr_hrs_ctg_Evening                                      uint8
#  68  arr_hrs_ctg_Morning                                      uint8
#  69  arr_hrs_ctg_Night                                        uint8
#  70  day_of_week_Friday                                       uint8
#  71  day_of_week_Monday                                       uint8
#  72  day_of_week_Saturday                                     uint8
#  73  day_of_week_Sunday                                       uint8
#  74  day_of_week_Thursday                                     uint8
#  75  day_of_week_Tuesday                                      uint8
#  76  day_of_week_Wednesday                                    uint8
#  77  haul_length_long                                         uint8
#  78  haul_length_medium                                       uint8
#  79  haul_length_short                                        uint8
# dtypes: float64(35), int64(19), uint8(26)
# memory usage: 2.0 GB

# %% [markdown]
# ### Preprocessing

# %%
# Arrival Delays with outliers
fig, ax = plt.subplots(figsize = (10,5))
ax.set_ylabel('Density (Number of flights)')
ax.set_xlabel('Delay (minutes)')
sns.histplot(x = df_flight['arr_delay'], kde = True)
# Out:
# <AxesSubplot:xlabel='Delay (minutes)', ylabel='Density (Number of flights)'>

# %%
# Upper limit and lower limit using 3 standard deviations.
upper = df_flight.arr_delay.mean() + 3 * df_flight.arr_delay.std()
lower = df_flight.arr_delay.mean() - 3 * df_flight.arr_delay.std()
print(upper)
print(lower)
# Out:
# 157.3344825342959
# -146.38320794042147

# %%
# Filter out the outliers
df_flight = df_flight[(df_flight.arr_delay < upper) & (df_flight.arr_delay > lower)]

# %%
# Arrival Delays without outliers
fig, ax = plt.subplots(figsize = (10,5))
ax.set_ylabel('Density (Number of flights)')
ax.set_xlabel('Delay (minutes)')

sns.histplot(x = df_flight['arr_delay'], kde = True)
# Out:
# <AxesSubplot:xlabel='Delay (minutes)', ylabel='Density (Number of flights)'>

# %%
# Departure Delays with outliers
fig, ax = plt.subplots(figsize = (10,5))
ax.set_ylabel('Density (Number of flights)')
ax.set_xlabel('Delay (minutes)')
sns.histplot(x = df_flight['dep_delay'], kde = True)
# Out:
# <AxesSubplot:xlabel='Delay (minutes)', ylabel='Density (Number of flights)'>

# %%
# Upper limit and lower limit using 3 standard deviations.
upper = df_flight.arr_delay.mean() + 3 * df_flight.arr_delay.std()
lower = df_flight.arr_delay.mean() - 3 * df_flight.arr_delay.std()
print(upper)
print(lower)
# Out:
# 86.66926622098944
# -84.84954469476065

# %%
# Filter out the outliers
df_flight = df_flight[(df_flight.arr_delay < upper) & (df_flight.arr_delay > lower)]

# %%
# Departure Delays without outliers
fig, ax = plt.subplots(figsize = (10,5))
ax.set_ylabel('Density (Number of flights)')
ax.set_xlabel('Delay (minutes)')

sns.histplot(x = df_flight['dep_delay'], kde = True)
# Out:
# <AxesSubplot:xlabel='Delay (minutes)', ylabel='Density (Number of flights)'>

# %%
# Save pd as csv
df_flight.to_csv('data_for_modeling_final_2022-10-28_1227.csv', index=False)
